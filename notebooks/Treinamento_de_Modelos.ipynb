# %%
# Importar as bibliotecas necessárias
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

# Definir diretório base
base_dir = 'C:/Users/gutoe/Desktop/IATrabalhoFinal'

# Função para treinar um modelo
def train_model(train_dir, validation_dir, num_classes, model_name, epochs):
    # Pré-processamento dos dados
    train_datagen = ImageDataGenerator(rescale=1./255)
    validation_datagen = ImageDataGenerator(rescale=1./255)

    train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='categorical')

    validation_generator = validation_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='categorical')

    # Verificar o número de classes nos dados
    print(f"Train classes: {train_generator.num_classes}, Validation classes: {validation_generator.num_classes}")

    # Construção do modelo
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(num_classes, activation='softmax')  # Número de classes
    ])

    model.compile(loss='categorical_crossentropy',
                  optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4),
                  metrics=['accuracy'])

    # Treinamento do modelo
    history = model.fit(
        train_generator,
        steps_per_epoch=100,
        epochs=epochs,
        validation_data=validation_generator,
        validation_steps=50)

    # Salvando o modelo
    model.save(os.path.join(base_dir, f'models/{model_name}.h5'))

    return history

# Treinar modelos
train_dir_fruit = os.path.join(base_dir, 'datasets/train/fruit')
validation_dir_fruit = os.path.join(base_dir, 'datasets/validation/fruit')
history_fruit = train_model(train_dir_fruit, validation_dir_fruit, 20, 'fruit_model', 20)

train_dir_packages = os.path.join(base_dir, 'datasets/train/packages')
validation_dir_packages = os.path.join(base_dir, 'datasets/validation/packages')
history_packages = train_model(train_dir_packages, validation_dir_packages, 9, 'packages_model', 20)

train_dir_primary = os.path.join(base_dir, 'datasets/train/primary')
validation_dir_primary = os.path.join(base_dir, 'datasets/validation/primary')
history_primary = train_model(train_dir_primary, validation_dir_primary, 3, 'primary_model', 25)  # Ajustado para 3 classes

train_dir_vegetables = os.path.join(base_dir, 'datasets/train/vegetables')
validation_dir_vegetables = os.path.join(base_dir, 'datasets/validation/vegetables')
history_vegetables = train_model(train_dir_vegetables, validation_dir_vegetables, 15, 'vegetables_model', 20)  # Verificar número de classes
# Out:
# Found 1117 images belonging to 20 classes.
# Found 1117 images belonging to 20 classes.
# Train classes: 20, Validation classes: 20
# Epoch 1/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.2421 - loss: 2.7151 - val_accuracy: 0.2480 - val_loss: 2.6106
# Epoch 2/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 129ms/step - accuracy: 0.2543 - loss: 2.5304 - val_accuracy: 0.2222 - val_loss: 2.3393
# Epoch 3/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 18s 175ms/step - accuracy: 0.3134 - loss: 2.2166 - val_accuracy: 0.3320 - val_loss: 1.9955
# Epoch 4/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.3487 - loss: 1.9764 - val_accuracy: 0.3077 - val_loss: 1.8306
# Epoch 5/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 33s 328ms/step - accuracy: 0.4250 - loss: 1.7233 - val_accuracy: 0.4360 - val_loss: 1.6088
# Epoch 6/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 12s 114ms/step - accuracy: 0.4927 - loss: 1.5058 - val_accuracy: 0.4957 - val_loss: 1.3639
# Epoch 7/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 15s 143ms/step - accuracy: 0.5261 - loss: 1.3158 - val_accuracy: 0.5680 - val_loss: 1.2031
# Epoch 8/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 12s 119ms/step - accuracy: 0.5542 - loss: 1.1921 - val_accuracy: 0.4872 - val_loss: 1.2408
# Epoch 9/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 153ms/step - accuracy: 0.6179 - loss: 1.0872 - val_accuracy: 0.6290 - val_loss: 1.0629
# Epoch 10/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 12s 121ms/step - accuracy: 0.6268 - loss: 1.0391 - val_accuracy: 0.7094 - val_loss: 0.8813
# Epoch 11/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 162ms/step - accuracy: 0.6634 - loss: 0.9629 - val_accuracy: 0.6770 - val_loss: 0.9061
# Epoch 12/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 125ms/step - accuracy: 0.6805 - loss: 0.9111 - val_accuracy: 0.6752 - val_loss: 0.8160
# Epoch 13/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 17s 163ms/step - accuracy: 0.7225 - loss: 0.8141 - val_accuracy: 0.7490 - val_loss: 0.6938
# Epoch 14/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - accuracy: 0.7417 - loss: 0.7251 - val_accuracy: 0.6410 - val_loss: 0.8586
# Epoch 15/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 37s 366ms/step - accuracy: 0.7395 - loss: 0.7204 - val_accuracy: 0.8150 - val_loss: 0.5645
# Epoch 16/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 131ms/step - accuracy: 0.7485 - loss: 0.6849 - val_accuracy: 0.7179 - val_loss: 0.6866
# Epoch 17/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 19s 188ms/step - accuracy: 0.7772 - loss: 0.6127 - val_accuracy: 0.8300 - val_loss: 0.4933
# Epoch 18/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.7976 - loss: 0.5496 - val_accuracy: 0.6325 - val_loss: 0.8437
# Epoch 19/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 19s 185ms/step - accuracy: 0.8032 - loss: 0.5416 - val_accuracy: 0.8300 - val_loss: 0.4566
# Epoch 20/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 18s 176ms/step - accuracy: 0.8125 - loss: 0.4991 - val_accuracy: 0.8632 - val_loss: 0.3749
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Found 781 images belonging to 9 classes.
# Found 781 images belonging to 9 classes.
# Train classes: 9, Validation classes: 9
# Epoch 1/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 137ms/step - accuracy: 0.2786 - loss: 1.9299 - val_accuracy: 0.3047 - val_loss: 1.8399
# Epoch 2/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 106ms/step - accuracy: 0.3577 - loss: 1.7899 - val_accuracy: 0.3431 - val_loss: 1.6915
# Epoch 3/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 106ms/step - accuracy: 0.3593 - loss: 1.6609 - val_accuracy: 0.4648 - val_loss: 1.5328
# Epoch 4/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 12s 118ms/step - accuracy: 0.4084 - loss: 1.5413 - val_accuracy: 0.4827 - val_loss: 1.3918
# Epoch 5/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - accuracy: 0.4758 - loss: 1.4196 - val_accuracy: 0.5250 - val_loss: 1.3577
# Epoch 6/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 141ms/step - accuracy: 0.5272 - loss: 1.3008 - val_accuracy: 0.6120 - val_loss: 1.1382
# Epoch 7/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.5932 - loss: 1.1602 - val_accuracy: 0.6684 - val_loss: 0.9869
# Epoch 8/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 137ms/step - accuracy: 0.6229 - loss: 1.0398 - val_accuracy: 0.6556 - val_loss: 0.9594
# Epoch 9/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 122ms/step - accuracy: 0.6866 - loss: 0.9345 - val_accuracy: 0.7170 - val_loss: 0.8276
# Epoch 10/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 12s 119ms/step - accuracy: 0.7346 - loss: 0.8151 - val_accuracy: 0.6428 - val_loss: 0.9960
# Epoch 11/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.7600 - loss: 0.7598 - val_accuracy: 0.8195 - val_loss: 0.5879
# Epoch 12/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 15s 147ms/step - accuracy: 0.7930 - loss: 0.6629 - val_accuracy: 0.8335 - val_loss: 0.5426
# Epoch 13/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 131ms/step - accuracy: 0.8347 - loss: 0.5526 - val_accuracy: 0.8707 - val_loss: 0.4552
# Epoch 14/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 139ms/step - accuracy: 0.8421 - loss: 0.5390 - val_accuracy: 0.9129 - val_loss: 0.3781
# Epoch 15/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 229ms/step - accuracy: 0.8612 - loss: 0.4458 - val_accuracy: 0.8886 - val_loss: 0.3614
# Epoch 16/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 33s 312ms/step - accuracy: 0.8949 - loss: 0.4204 - val_accuracy: 0.9347 - val_loss: 0.2649
# Epoch 17/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 213ms/step - accuracy: 0.9104 - loss: 0.3316 - val_accuracy: 0.8937 - val_loss: 0.3246
# Epoch 18/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 138ms/step - accuracy: 0.8974 - loss: 0.3401 - val_accuracy: 0.9193 - val_loss: 0.2626
# Epoch 19/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 244ms/step - accuracy: 0.9221 - loss: 0.2595 - val_accuracy: 0.9449 - val_loss: 0.2216
# Epoch 20/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 138ms/step - accuracy: 0.9128 - loss: 0.2645 - val_accuracy: 0.9667 - val_loss: 0.1595
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Found 3602 images belonging to 3 classes.
# Found 3602 images belonging to 3 classes.
# Train classes: 3, Validation classes: 3
# Epoch 1/25
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 72
#      70 train_dir_primary = os.path.join(base_dir, 'datasets/train/primary')
#      71 validation_dir_primary = os.path.join(base_dir, 'datasets/validation/primary')
# ---> 72 history_primary = train_model(train_dir_primary, validation_dir_primary, 5, 'primary_model', 25)
#      74 train_dir_vegetables = os.path.join(base_dir, 'datasets/train/vegetables')
#      75 validation_dir_vegetables = os.path.join(base_dir, 'datasets/validation/vegetables')
#
# Cell In[3], line 49, in train_model(train_dir, validation_dir, num_classes, model_name, epochs)
#      44 model.compile(loss='categorical_crossentropy',
#      45               optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4),
#      46               metrics=['accuracy'])
#      48 # Treinamento do modelo
# ---> 49 history = model.fit(
#      50     train_generator,
#      51     steps_per_epoch=100,
#      52     epochs=epochs,
#      53     validation_data=validation_generator,
#      54     validation_steps=50)
#      56 # Salvando o modelo
#      57 model.save(os.path.join(base_dir, f'models/{model_name}.h5'))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\backend\tensorflow\nn.py:561, in categorical_crossentropy(target, output, from_logits, axis)
#     559 for e1, e2 in zip(target.shape, output.shape):
#     560     if e1 is not None and e2 is not None and e1 != e2:
# --> 561         raise ValueError(
#     562             "Arguments `target` and `output` must have the same shape. "
#     563             "Received: "
#     564             f"target.shape={target.shape}, output.shape={output.shape}"
#     565         )
#     567 output, from_logits = _get_logits(
#     568     output, from_logits, "Softmax", "categorical_crossentropy"
#     569 )
#     570 if from_logits:
#
# ValueError: Arguments `target` and `output` must have the same shape. Received: target.shape=(None, 3), output.shape=(None, 5)
